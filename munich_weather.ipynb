# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
weather = pd.read_csv("weather_data_munich.csv", index_col="date")

# %%
weather
# Out:
#            tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun
# date
# 1/1/1979    NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN    NaN
# 1/2/1979    NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN    NaN
# 1/3/1979   -8.9 -13.0  -7.0   NaN   NaN  258.0  16.4   NaN     NaN    NaN
# 1/4/1979    NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN    NaN
# 1/5/1979  -14.2 -17.0  -9.0   NaN   NaN  125.0   4.8   NaN     NaN    NaN
# ...         ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 11/8/2022   5.4  -2.4  14.1   0.0   0.0   84.0   4.0  17.3  1018.8  523.0
# 11/9/2022   7.9  -0.6  14.6   4.8   0.0  100.0   5.4  23.4  1018.4  194.0
# NaN         NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN    NaN
# NaN         NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN    NaN
# NaN         NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN    NaN
#
# [16022 rows x 10 columns]

# %%
weather.loc["1/1/1979"] #single date
weather.loc["1/1/1979":"1/30/1979",:] # slice through a period of time
# Out:
#            tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# date
# 1/1/1979    NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/2/1979    NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/3/1979   -8.9 -13.0  -7.0   NaN   NaN  258.0  16.4   NaN   NaN   NaN
# 1/4/1979    NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/5/1979  -14.2 -17.0  -9.0   NaN   NaN  125.0   4.8   NaN   NaN   NaN
# 1/6/1979  -12.0 -16.0  -8.0   NaN   NaN    NaN   2.3   NaN   NaN   NaN
# 1/7/1979    NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/8/1979    NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/9/1979    1.5  -1.0   3.0   NaN   NaN    NaN   8.7   NaN   NaN   NaN
# 1/10/1979  -0.1  -3.0   2.0   NaN   NaN  198.0  11.5   NaN   NaN   NaN
# 1/11/1979   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/12/1979   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/13/1979   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/14/1979  -3.3  -4.0  -2.0   NaN   NaN  263.0  17.5   NaN   NaN   NaN
# 1/15/1979   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/16/1979  -6.3  -7.0  -5.0   NaN   NaN  277.0   8.8   NaN   NaN   NaN
# 1/17/1979  -8.0 -11.0  -6.0   NaN   NaN  135.0   9.1   NaN   NaN   NaN
# 1/18/1979 -10.4 -15.0  -8.0   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/19/1979   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/20/1979   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/21/1979  -4.4  -5.0  -3.0   NaN   NaN    NaN   3.3   NaN   NaN   NaN
# 1/22/1979   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/23/1979   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/24/1979   1.3  -2.0   4.0   NaN   NaN  253.0  10.5   NaN   NaN   NaN
# 1/25/1979   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN   NaN
# 1/26/1979  -3.8 -12.0   2.0   NaN   NaN    NaN   5.3   NaN   NaN   NaN
# 1/27/1979   0.2  -2.0   3.0   NaN   NaN    NaN   6.4   NaN   NaN   NaN
# 1/28/1979   0.4  -2.0   2.0   NaN   NaN    NaN   5.8   NaN   NaN   NaN
# 1/29/1979  -0.7  -5.0   1.0   NaN   NaN    NaN   4.6   NaN   NaN   NaN
# 1/30/1979  -0.3  -5.0   3.0   NaN   NaN  207.0  11.2   NaN   NaN   NaN

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]*100
# Out:
# tavg     4.462614
# tmin     4.462614
# tmax     4.462614
# prcp    30.508051
# snow    33.091999
# wdir    17.257521
# wspd     4.762202
# wpgt    30.913744
# pres    14.692298
# tsun    30.564224
# dtype: float64

# %%
weather.plot(y="prcp")
# Out:
# <AxesSubplot:xlabel='date'>

# %%
new_weather = weather.loc["5/19/1992":"11/9/2022",:]

# %%
new_weather
# Out:
#            tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun
# date
# 5/19/1992  13.2   6.4  18.2   0.0   0.0   81.0  22.2  53.3  1024.9  702.0
# 5/20/1992  14.9   9.7  20.3   0.0   0.0   92.0  28.1  65.5  1021.0  786.0
# 5/21/1992  12.4   7.7  20.5   0.0   0.0  102.0  11.5  36.0  1019.2  522.0
# 5/22/1992  16.1   4.5  22.0   0.0   0.0   78.0   9.7  31.3  1016.8  798.0
# 5/23/1992  17.9  10.1  24.5   0.0   0.0   78.0  17.6  48.2  1013.4  654.0
# ...         ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 11/5/2022   6.4   0.6   9.4   4.0   0.0  237.0   8.3  22.3  1020.4   14.0
# 11/6/2022   5.1  -0.6  10.0   0.2   0.0  101.0   9.7  54.7  1020.2  264.0
# 11/7/2022   9.1   1.0  15.2   0.0   0.0  223.0  10.1  33.5  1020.2  490.0
# 11/8/2022   5.4  -2.4  14.1   0.0   0.0   84.0   4.0  17.3  1018.8  523.0
# 11/9/2022   7.9  -0.6  14.6   4.8   0.0  100.0   5.4  23.4  1018.4  194.0
#
# [11132 rows x 10 columns]

# %%
new_weather.apply(pd.isnull).sum()/new_weather.shape[0]*100
# Out:
# tavg    0.000000
# tmin    0.000000
# tmax    0.000000
# prcp    0.000000
# snow    3.719008
# wdir    0.547970
# wspd    0.161696
# wpgt    0.565936
# pres    0.000000
# tsun    0.080848
# dtype: float64

# %% [markdown]
# snow we will replace with 0 since most of the NaN values are located in spring, summer or autum season
# wdir
# wspd
# wpgt
# tsun will replace NaN values with 'fill' method.

# %%
clean_weather = new_weather.fillna(0)

# %%
clean_weather
# Out:
#            tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun
# date
# 5/19/1992  13.2   6.4  18.2   0.0   0.0   81.0  22.2  53.3  1024.9  702.0
# 5/20/1992  14.9   9.7  20.3   0.0   0.0   92.0  28.1  65.5  1021.0  786.0
# 5/21/1992  12.4   7.7  20.5   0.0   0.0  102.0  11.5  36.0  1019.2  522.0
# 5/22/1992  16.1   4.5  22.0   0.0   0.0   78.0   9.7  31.3  1016.8  798.0
# 5/23/1992  17.9  10.1  24.5   0.0   0.0   78.0  17.6  48.2  1013.4  654.0
# ...         ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 11/5/2022   6.4   0.6   9.4   4.0   0.0  237.0   8.3  22.3  1020.4   14.0
# 11/6/2022   5.1  -0.6  10.0   0.2   0.0  101.0   9.7  54.7  1020.2  264.0
# 11/7/2022   9.1   1.0  15.2   0.0   0.0  223.0  10.1  33.5  1020.2  490.0
# 11/8/2022   5.4  -2.4  14.1   0.0   0.0   84.0   4.0  17.3  1018.8  523.0
# 11/9/2022   7.9  -0.6  14.6   4.8   0.0  100.0   5.4  23.4  1018.4  194.0
#
# [11132 rows x 10 columns]

# %%
clean_weather.apply(pd.isnull).sum()/clean_weather.shape[0]
# Out:
# tavg    0.0
# tmin    0.0
# tmax    0.0
# prcp    0.0
# snow    0.0
# wdir    0.0
# wspd    0.0
# wpgt    0.0
# pres    0.0
# tsun    0.0
# dtype: float64

# %% [markdown]
# creating a datafram snow_data we replace all values with the fill method. We then replace the snow colum from the snow_data dataframe into the clean_weather snow colum

# %%
snow_data = new_weather.fillna(method = "ffill")

# %%
clean_weather["snow"] = snow_data["snow"]

# %%
clean_weather
# Out:
#            tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun
# date
# 5/19/1992  13.2   6.4  18.2   0.0   0.0   81.0  22.2  53.3  1024.9  702.0
# 5/20/1992  14.9   9.7  20.3   0.0   0.0   92.0  28.1  65.5  1021.0  786.0
# 5/21/1992  12.4   7.7  20.5   0.0   0.0  102.0  11.5  36.0  1019.2  522.0
# 5/22/1992  16.1   4.5  22.0   0.0   0.0   78.0   9.7  31.3  1016.8  798.0
# 5/23/1992  17.9  10.1  24.5   0.0   0.0   78.0  17.6  48.2  1013.4  654.0
# ...         ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 11/5/2022   6.4   0.6   9.4   4.0   0.0  237.0   8.3  22.3  1020.4   14.0
# 11/6/2022   5.1  -0.6  10.0   0.2   0.0  101.0   9.7  54.7  1020.2  264.0
# 11/7/2022   9.1   1.0  15.2   0.0   0.0  223.0  10.1  33.5  1020.2  490.0
# 11/8/2022   5.4  -2.4  14.1   0.0   0.0   84.0   4.0  17.3  1018.8  523.0
# 11/9/2022   7.9  -0.6  14.6   4.8   0.0  100.0   5.4  23.4  1018.4  194.0
#
# [11132 rows x 10 columns]

# %%
clean_weather.apply(pd.isnull).sum()/clean_weather.shape[0]*100
# Out:
# tavg    0.0
# tmin    0.0
# tmax    0.0
# prcp    0.0
# snow    0.0
# wdir    0.0
# wspd    0.0
# wpgt    0.0
# pres    0.0
# tsun    0.0
# dtype: float64

# %% [markdown]
# Now we have a perfectly clean data set and we are ready to train our model

# %%
clean_weather.index = pd.to_datetime(clean_weather.index)

# %%
clean_weather.plot(y="tmax")
# Out:
# <AxesSubplot:xlabel='date'>

# %%
clean_weather["target"] = clean_weather.shift(-1)["snow"]

# %%
clean_weather
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun  \
# date
# 1992-05-19  13.2   6.4  18.2   0.0   0.0   81.0  22.2  53.3  1024.9  702.0
# 1992-05-20  14.9   9.7  20.3   0.0   0.0   92.0  28.1  65.5  1021.0  786.0
# 1992-05-21  12.4   7.7  20.5   0.0   0.0  102.0  11.5  36.0  1019.2  522.0
# 1992-05-22  16.1   4.5  22.0   0.0   0.0   78.0   9.7  31.3  1016.8  798.0
# 1992-05-23  17.9  10.1  24.5   0.0   0.0   78.0  17.6  48.2  1013.4  654.0
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 2022-11-05   6.4   0.6   9.4   4.0   0.0  237.0   8.3  22.3  1020.4   14.0
# 2022-11-06   5.1  -0.6  10.0   0.2   0.0  101.0   9.7  54.7  1020.2  264.0
# 2022-11-07   9.1   1.0  15.2   0.0   0.0  223.0  10.1  33.5  1020.2  490.0
# 2022-11-08   5.4  -2.4  14.1   0.0   0.0   84.0   4.0  17.3  1018.8  523.0
# 2022-11-09   7.9  -0.6  14.6   4.8   0.0  100.0   5.4  23.4  1018.4  194.0
#
#             target
# date
# 1992-05-19     0.0
# 1992-05-20     0.0
# 1992-05-21     0.0
# 1992-05-22     0.0
# 1992-05-23     0.0
# ...            ...
# 2022-11-05     0.0
# 2022-11-06     0.0
# 2022-11-07     0.0
# 2022-11-08     0.0
# 2022-11-09     NaN
#
# [11132 rows x 11 columns]

# %%
clean_weather.iloc[11119,10] = 0
clean_weather
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun  \
# date
# 1992-05-19  13.2   6.4  18.2   0.0   0.0   81.0  22.2  53.3  1024.9  702.0
# 1992-05-20  14.9   9.7  20.3   0.0   0.0   92.0  28.1  65.5  1021.0  786.0
# 1992-05-21  12.4   7.7  20.5   0.0   0.0  102.0  11.5  36.0  1019.2  522.0
# 1992-05-22  16.1   4.5  22.0   0.0   0.0   78.0   9.7  31.3  1016.8  798.0
# 1992-05-23  17.9  10.1  24.5   0.0   0.0   78.0  17.6  48.2  1013.4  654.0
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 2022-11-05   6.4   0.6   9.4   4.0   0.0  237.0   8.3  22.3  1020.4   14.0
# 2022-11-06   5.1  -0.6  10.0   0.2   0.0  101.0   9.7  54.7  1020.2  264.0
# 2022-11-07   9.1   1.0  15.2   0.0   0.0  223.0  10.1  33.5  1020.2  490.0
# 2022-11-08   5.4  -2.4  14.1   0.0   0.0   84.0   4.0  17.3  1018.8  523.0
# 2022-11-09   7.9  -0.6  14.6   4.8   0.0  100.0   5.4  23.4  1018.4  194.0
#
#             target
# date
# 1992-05-19     0.0
# 1992-05-20     0.0
# 1992-05-21     0.0
# 1992-05-22     0.0
# 1992-05-23     0.0
# ...            ...
# 2022-11-05     0.0
# 2022-11-06     0.0
# 2022-11-07     0.0
# 2022-11-08     0.0
# 2022-11-09     NaN
#
# [11132 rows x 11 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=0.1)

# %%
predictors = ["tavg","tmax","tmin","prcp","snow","wdir","wspd","wpgt","pres","tsun"]

# %%
train = clean_weather.loc[:"2020-12-31"]

# %%
test = clean_weather.loc["2021-01-01":"2021-12-25"]
test
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun  \
# date
# 2021-01-01  -1.4  -6.9   3.5   0.0   0.0  349.0   3.2  13.0  1010.6  321.0
# 2021-01-02  -1.8  -3.6   0.3   0.0   0.0   17.0   6.5  18.4  1013.3    0.0
# 2021-01-03  -0.6  -1.9   0.5   0.0   0.0  231.0   5.4  16.6  1012.6    0.0
# 2021-01-04  -0.7  -1.3   0.3   0.0   0.0   82.0   6.1  20.5  1014.9    0.0
# 2021-01-05  -0.8  -1.4  -0.1   3.1   0.0  120.0   5.8  20.5  1013.7    0.0
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 2021-12-21  -4.4  -8.8   0.1   0.0   0.0   44.0   5.0  20.5  1028.0  366.0
# 2021-12-22  -6.3 -10.9  -1.2   0.0   0.0   97.0   5.0  26.6  1029.2  449.0
# 2021-12-23  -2.8 -10.1   7.2   1.1   0.0  186.0   6.5  30.6  1019.7   87.0
# 2021-12-24   6.6   4.8   8.1   6.7   0.0  242.0  22.0  48.2  1009.4    0.0
# 2021-12-25   5.4   1.1   8.4   2.3   0.0  249.0  10.4  22.3  1007.4    0.0
#
#             target
# date
# 2021-01-01     0.0
# 2021-01-02     0.0
# 2021-01-03     0.0
# 2021-01-04     0.0
# 2021-01-05    30.0
# ...            ...
# 2021-12-21     0.0
# 2021-12-22     0.0
# 2021-12-23     0.0
# 2021-12-24     0.0
# 2021-12-25     0.0
#
# [359 rows x 11 columns]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"], predictions)
# Out:
# 3.3795612738949856

# %%
reg.coef_
# Out:
# array([-0.1386892 , -0.13679756,  0.05462195,  0.12646878,  0.87060356,
#         0.0054492 ,  0.07286255, -0.04301529, -0.10163218,  0.00312959])

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis = 1)

# %%
combined.columns= ["actual","predictions"]
combined
# Out:
#             actual  predictions
# date
# 2021-01-01     0.0     4.947871
# 2021-01-02     0.0     2.541373
# 2021-01-03     0.0     3.674995
# 2021-01-04     0.0     2.586555
# 2021-01-05    30.0     3.348904
# ...            ...          ...
# 2021-12-21     0.0     2.244231
# 2021-12-22     0.0     2.735084
# 2021-12-23     0.0     1.538190
# 2021-12-24     0.0     3.085479
# 2021-12-25     0.0     2.962602
#
# [359 rows x 2 columns]

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
combined_new= combined.loc["2021-12-01":"2021-12-25",:]

# %%
combined_new.plot()
# Out:
# <AxesSubplot:xlabel='date'>
